# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt



hss=pd.read_csv('hss.csv')
hss
# Out:
#         TV      Radio  Social Media Influencer       Sales
# 0     16.0   6.566231      2.907983       Mega   54.732757
# 1     13.0   9.237765      2.409567       Mega   46.677897
# 2     41.0  15.886446      2.913410       Mega  150.177829
# 3     83.0  30.020028      6.922304       Mega  298.246340
# 4     15.0   8.437408      1.405998      Micro   56.594181
# ...    ...        ...           ...        ...         ...
# 4567  26.0   4.472360      0.717090      Micro   94.685866
# 4568  71.0  20.610685      6.545573       Nano  249.101915
# 4569  44.0  19.800072      5.096192      Micro  163.631457
# 4570  71.0  17.534640      1.940873      Macro  253.610411
# 4571  42.0  15.966688      5.046548      Micro  148.202414
#
# [4572 rows x 5 columns]

# %%
hss.head()
# Out:
#      TV      Radio  Social Media Influencer       Sales
# 0  16.0   6.566231      2.907983       Mega   54.732757
# 1  13.0   9.237765      2.409567       Mega   46.677897
# 2  41.0  15.886446      2.913410       Mega  150.177829
# 3  83.0  30.020028      6.922304       Mega  298.246340
# 4  15.0   8.437408      1.405998      Micro   56.594181

# %%
hss.isna().sum()
# Out:
# TV              10
# Radio            4
# Social Media     6
# Influencer       0
# Sales            6
# dtype: int64

# %%
hss.describe().T
# Out:
#                count        mean        std        min         25%  \
# TV            4562.0   54.066857  26.125054  10.000000   32.000000
# Radio         4568.0   18.160356   9.676958   0.000684   10.525957
# Social Media  4566.0    3.323956   2.212670   0.000031    1.527849
# Sales         4566.0  192.466602  93.133092  31.199409  112.322882
#
#                      50%         75%         max
# TV             53.000000   77.000000  100.000000
# Radio          17.859513   25.649730   48.871161
# Social Media    3.055565    4.807558   13.981662
# Sales         189.231172  272.507922  364.079751

# %%
import seaborn  as sns
sns.distplot(hss.TV)
# Out:
# C:\Users\90545\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='TV', ylabel='Density'>

# %%
sns.distplot(hss['Social Media']) # right skew we can fill the missing values with median
# Out:
# C:\Users\90545\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Social Media', ylabel='Density'>

# %%
plt.figure(figsize=(12,8))
sns.boxplot(hss['Radio'])
plt.show()
# for outlier detection we can see
# Out:
# C:\Users\90545\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.boxplot(hss['Social Media']) # we can see some outliers but that is social media  ı dont want to delete whole outliers
#maybe some new trends are here ı can extract that so ı will not delete
# Out:
# C:\Users\90545\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Social Media'>

# %%
g=sns.FacetGrid(hss,col='Influencer')
g.map(plt.hist,'Sales',bins=30)

# %%
hss[['Influencer','Sales']].groupby('Influencer').mean().sort_values(by='Sales')
# We can see some macro Influencers had big impact of Influencer.
# I think between these values are not a big differences so we can do directly one hot encoding  or label encoding for our future engineering
# Out:
#                  Sales
# Influencer
# Mega        190.593666
# Micro       191.809095
# Nano        191.934304
# Macro       195.613601

# %%
hss.corr()
# We can see correct relationship  Sales with Radio and Tv
# We must use these informations
# Out:
#                     TV     Radio  Social Media     Sales
# TV            1.000000  0.869460      0.528168  0.999497
# Radio         0.869460  1.000000      0.607452  0.869105
# Social Media  0.528168  0.607452      1.000000  0.528906
# Sales         0.999497  0.869105      0.528906  1.000000

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x=hss['Social Media'],y=hss['Sales'],hue=hss['Influencer'])
plt.show()

# %%
# tv and sales had super relation and radio and sales has super relation

#hss['Radio'].fillna(hss.Radio.mean(),inplace=True)
#hss['Social Media'].fillna(hss['Social Media'].mean(),inplace=True)
#hss['Sales'].fillna(hss.Sales.mean(),inplace=True)

# %%
# we must some data preprocessing 
# we can start with missing values
hss.isna().sum()
# Out:
# TV              10
# Radio            4
# Social Media     6
# Influencer       0
# Sales            6
# dtype: int64

# %%
sns.distplot(hss['Radio']) # kind a normal distribution so ı can use mean, to fill missing values
# Out:
# C:\Users\90545\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Radio', ylabel='Density'>

# %%
hss['Radio'].fillna(hss['Radio'].mean(),inplace=True)

# %%
sns.distplot(hss['TV'])  # ı can use mean too
# Out:
# C:\Users\90545\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='TV', ylabel='Density'>

# %%
hss['TV'].fillna(hss['TV'].mean(),inplace=True)

# %%
sns.distplot(hss['Social Media'])  # right skew data so ı can use median to filling the missing values because ı want to 
#declare to the average value
# Out:
# C:\Users\90545\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Social Media', ylabel='Density'>

# %%
hss['Social Media'].fillna(hss['Social Media'].median(),inplace=True)

# %%
hss.isna().sum()
# Out:
# TV              0
# Radio           0
# Social Media    0
# Influencer      0
# Sales           6
# dtype: int64

# %%
sns.distplot(hss['Sales'])  # we can use mean kind a normal distribution
# Out:
# C:\Users\90545\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Sales', ylabel='Density'>

# %%
hss['Sales'].fillna(hss['Sales'].mean(),inplace=True)

# %%
hss.isna().sum() # we have no missing values we got it
# Out:
# TV              0
# Radio           0
# Social Media    0
# Influencer      0
# Sales           0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split,RandomizedSearchCV
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression

# %%
# feature engineering
X=hss[['TV','Radio','Social Media']]
y=hss['Sales']
# firstly ı want to add influencer because ı must encode .machine cannot get it with String data

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
print(len(X_train))
print(len(X_test))
print(len(y_train))
print(len(y_test))
# I should check it my dataset has distributed correctly ok everything is fine lets contuniue!
# Out:
# 3657
# 915
# 3657
# 915

# %%
lr=LinearRegression(normalize=True)
lr
# Out:
# LinearRegression(normalize=True)

# %%
#We are fitting our values
lr.fit(X_train,y_train)
# Out:
# LinearRegression(normalize=True)

# %%
lr.score(X_test,y_test)
# Out:
# 0.9983364299771089

# %%
# We must use ınfluencer_encoded

# %%
hss['Influencer_Encoded']=pd.factorize(hss['Influencer'])[0]

# %%
# feature engineering
X=hss[['TV','Radio','Social Media']]
y=hss['Sales']
# firstly ı want to add influencer because ı must encode .machine cannot get it with String data

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
lr=LinearRegression(normalize=True)
lr
# Out:
# LinearRegression(normalize=True)

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression(normalize=True)

# %%
lr.score(X_test,y_test)
# Out:
# 0.9935377590763033

# %%
predictions=lr.predict(X_test)
score=mean_squared_error(predictions,y_test)
score
# Out:
# 55.696423197742575

# %%
# we can do hyperparameter tuning because our error is big

# %%
lr_parameters={'n_jobs':[100,200,500],
    'fit_intercept':['auto','sqrt','log2'],
    'normalize':[6,8,10]
              }

# %%
random_search=RandomizedSearchCV(lr,lr_parameters,cv=5)
random_search.fit(X_train,y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=LinearRegression(normalize=True),
#                    param_distributions={'fit_intercept': ['auto', 'sqrt',
#                                                           'log2'],
#                                         'n_jobs': [100, 200, 500],
#                                         'normalize': [6, 8, 10]})

# %%
lr.score(X_test,y_test)
# Out:
# 0.9935377590763033

# %%
# We have good values
# we can see best params nd bes accuracy
print(random_search.best_params_)
print(random_search.best_score_)
# Out:
# {'normalize': 10, 'n_jobs': 100, 'fit_intercept': 'sqrt'}
# 0.9932709047862138

# %%
predictions=random_search.predict(X_test)
score=mean_squared_error(predictions,y_test)
score
# Out:
# 55.696423197742575
